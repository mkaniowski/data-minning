# %%
import os

current_path = os.getcwd()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("load-extension=C:/Users/kanio/AppData/Local/Google/Chrome/User Data/Default/Extensions/cjpalhdlnbpafiamejdnhcphjbkeiagm/1.61.2_0")

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# %%
urls_path = f"{current_path}/../data/technologia_urls.csv"

# %%
from src.webscrape.technologia.get_urls import get_urls

get_urls(urls_path, driver, None, True)
# Out:
# No back button found or failed to click
# #1 Collected: "Własny, suwerenny internet". Putin testuje nowe rozwiązanie. "Może całkowicie odizolować rosyjskich użytkowników od reszty świata" - https://wiadomosci.onet.pl/swiat/putin-wszedl-na-nowy-poziom-cenzury-wlasnie-tworzy-wlasny-internet/zyfwv2l
# #2 Collected: Mała zmiana w ustawie. Może pociągnąć za sobą miliardowe skutki - https://wiadomosci.onet.pl/kraj/zmiany-w-przepisach-o-cyberbezpieczenstwie-chodzi-o-dostawcow-wysokiego-ryzyka/mmxmygj
# #3 Collected: Jak naładować telefon bez ładowarki? Jest kilka sprawdzonych sposobów - https://wiadomosci.onet.pl/kraj/brak-ladowarki-to-nie-problem-sprawdz-jak-latwo-podladowac-telefon/m93e97s
# #4 Collected: "Żądło w ogonie" chińskiego smoka. Jeśli wygra tę wojnę z Wujem Samem, konsekwencje dla świata będą poważne - https://wiadomosci.onet.pl/swiat/dwa-supermocarstwa-walcza-o-wplywy-usa-juz-nie-naprawia-bledu-trumpa/n8s83vs
# ...

# %%
from src.webscrape.technologia.get_urls_geekweek import get_urls

get_urls(urls_path, driver, None, True)
# Out:
# Error processing article: Message: no such element: Unable to locate element: {"method":"tag name","selector":"span"}
#   (Session info: chrome=131.0.6778.140); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x009534A3+25059]
# 	(No symbol) [0x008DCEA4]
# 	(No symbol) [0x007BBEC3]
# 	(No symbol) [0x007FFD86]
# 	(No symbol) [0x007FFFCB]
# 	(No symbol) [0x007F5B01]
# 	(No symbol) [0x00821F44]
# 	(No symbol) [0x007F5A24]
# 	(No symbol) [0x00822194]
# 	(No symbol) [0x0083B51E]
# 	(No symbol) [0x00821C96]
# 	(No symbol) [0x007F3FAC]
# 	(No symbol) [0x007F4F3D]
# 	GetHandleVerifier [0x00C45613+3113811]
# 	GetHandleVerifier [0x00C5A2DA+3199002]
# 	GetHandleVerifier [0x00C52AB2+3168242]
# 	GetHandleVerifier [0x009F3310+680016]
# 	(No symbol) [0x008E57ED]
# 	(No symbol) [0x008E2A98]
# 	(No symbol) [0x008E2C35]
# 	(No symbol) [0x008D5890]
# ...

# %%
from src.utils.process_urls import process_urls
from src.webscrape.technologia.get_content import get_content

input_path = f"{current_path}/../data/technologia_urls_3.csv"
output_path = f"{current_path}/../data/technologia_content.csv"

process_urls(input_path, output_path, get_content, driver)
# Out:
# 2777it [51:28,  1.11s/it]

# %%
from src.webscrape.technologia.get_urls_bi import get_urls

get_urls(urls_path, driver, None, True)
# Out:
# Error processing article: Message: no such element: Unable to locate element: {"method":"tag name","selector":"h2"}
#   (Session info: chrome=131.0.6778.140); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x002C34A3+25059]
# 	(No symbol) [0x0024CEA4]
# 	(No symbol) [0x0012BEC3]
# 	(No symbol) [0x0016FD86]
# 	(No symbol) [0x0016FFCB]
# 	(No symbol) [0x00165B01]
# 	(No symbol) [0x00191F44]
# 	(No symbol) [0x00165A24]
# 	(No symbol) [0x00192194]
# 	(No symbol) [0x001AB51E]
# 	(No symbol) [0x00191C96]
# 	(No symbol) [0x00163FAC]
# 	(No symbol) [0x00164F3D]
# 	GetHandleVerifier [0x005B5613+3113811]
# 	GetHandleVerifier [0x005CA2DA+3199002]
# 	GetHandleVerifier [0x005C2AB2+3168242]
# 	GetHandleVerifier [0x00363310+680016]
# 	(No symbol) [0x002557ED]
# 	(No symbol) [0x00252A98]
# 	(No symbol) [0x00252C35]
# 	(No symbol) [0x00245890]
# ...

# %%
from src.utils.process_urls import process_urls
from src.webscrape.technologia.get_content_bi import get_content

input_path = f"{current_path}/../data/technologia_urls_4.csv"
output_path = f"{current_path}/../data/technologia_content_bi.csv"

process_urls(input_path, output_path, get_content, driver)
# Out:
# 1015it [20:28,  1.21s/it]
