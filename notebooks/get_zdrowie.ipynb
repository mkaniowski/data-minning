# %%
import os

current_path = os.getcwd()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
chrome_options.add_argument("load-extension=C:/Users/kanio/AppData/Local/Google/Chrome/User Data/Default/Extensions/cjpalhdlnbpafiamejdnhcphjbkeiagm/1.61.2_0")

# %%
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# %%
urls_path = f"{current_path}/../data/zdrowie_urls.csv"

# %%
from src.webscrape.zdrowie.get_urls import get_urls

get_urls(urls_path, driver, None, True)
# Out:
# #1 Collected: Ta herbata postawi cię na nogi. W dodatku kosztuje grosze! - https://kobieta.onet.pl/zdrowie/ta-herbata-postawi-cie-na-nogi-w-dodatku-kosztuje-grosze/f5xjwgw
# #2 Collected: Grecy tę herbatę piją codziennie. Dzięki temu rzadziej chorują na Alzheimera - https://kobieta.onet.pl/zdrowie/picie-tego-ziola-przeciwdziala-powstawaniu-zmarszczek-jest-tanie-i-latwo-dostepne/72sq4w7
# #3 Collected: Oto wysokość średniej emerytury w Polsce. ZUS podał dane - https://kobieta.onet.pl/zdrowie/wiadomosci/oto-wysokosc-sredniej-emerytury-w-polsce-zus-podal-dane/h4t5wv9
# #4 Collected: Poduszka masująca to najlepsza inwestycja w zdrowie — pomaga na chroniczny ból. Tańsza niż wizyty u masażysty - https://kobieta.onet.pl/zdrowie/poduszka-masujaca-to-najlepsza-inwestycja-w-zdrowie-pomaga-na-chroniczny-bol-tansza/4xj4nmc
# ...

# %%
from src.utils.process_urls import process_urls
from src.webscrape.zdrowie.get_content import get_content

input_path = f"{current_path}/../data/zdrowie_urls.csv"
output_path = f"{current_path}/../data/zdrowie_content.csv"

process_urls(input_path, output_path, get_content, driver)
# Out:
# 928it [24:08,  1.56s/it]

# %%
from src.webscrape.zdrowie.get_urls_interia import get_urls

get_urls(urls_path, driver, 4000, True)
# Out:
# #1 Collected: Śpisz przy kaloryferze? Zmęczenie, bóle głowy i drapanie w gardle to tylko część problemów - https://zdrowie.interia.pl/zdrowie/news-spisz-przy-kaloryferze-zmeczenie-bole-glowy-i-drapanie-w-gar,nId,7876207
# #2 Collected: Zespół przewlekłego zmęczenia to nie objaw a choroba. Lekarka: dotyczy osób w każdym wieku - https://zdrowie.interia.pl/zdrowie/news-zespol-przewleklego-zmeczenia-to-nie-objaw-a-choroba-lekarka,nId,7874996
# Error processing article: Message: no such element: Unable to locate element: {"method":"tag name","selector":"span"}
#   (Session info: chrome=131.0.6778.140); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x002C34A3+25059]
# 	(No symbol) [0x0024CEA4]
# 	(No symbol) [0x0012BEC3]
# 	(No symbol) [0x0016FD86]
# 	(No symbol) [0x0016FFCB]
# 	(No symbol) [0x00165B01]
# 	(No symbol) [0x00191F44]
# ...
