# %%
from src.classification.pipeline_classification import pipeline_classification

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes',
    'max_iter': 1000
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# Accuracy: 0.83

# %%
# print(xd['tokens'][0])

# %%
configs = [{
    'tokenizer': 'tfidf',
    'model': 'naive_bayes',
    'max_iter': 1000,
    'normalization': False
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# Accuracy: 0.84

# %%
# print(jprld['tokens'][0])

# %%
configs = [{
    'tokenizer': 'word2vec',
    'model': 'naive_bayes',
    'max_iter': 1000,
    'normalization': False,
    'padding': False,
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# Accuracy: 0.83

# %%
# print(aha['tokens'][0])

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression',
    'max_iter': 1000
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 02:33:20,499] A new study created in RDB with name: logistic_regression_count
# [I 2025-01-05 02:33:20,871] Trial 0 finished with value: 0.817 and parameters: {'C': 0.003341177861955664, 'solver': 'liblinear', 'class_weight': None}. Best is trial 0 with value: 0.817.
# [I 2025-01-05 02:33:21,154] Trial 1 finished with value: 0.839 and parameters: {'C': 0.547548898961983, 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.839.
# [I 2025-01-05 02:33:22,101] Trial 2 finished with value: 0.832 and parameters: {'C': 0.06985683504099668, 'solver': 'lbfgs', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.839.
# [I 2025-01-05 02:33:22,405] Trial 3 finished with value: 0.84 and parameters: {'C': 1.2010472749973093, 'solver': 'liblinear', 'class_weight': None}. Best is trial 3 with value: 0.84.
# ...

# %%
configs = [{
    'tokenizer': 'tfidf',
    'model': 'logistic_regression',
    'max_iter': 1000,
    'normalization': False
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 02:33:47,225] A new study created in RDB with name: logistic_regression_tfidf
# [I 2025-01-05 02:33:47,609] Trial 0 finished with value: 0.851 and parameters: {'C': 1.0786604960104467, 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.851.
# [I 2025-01-05 02:33:47,962] Trial 1 finished with value: 0.822 and parameters: {'C': 42.4130520493544, 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.851.
# [I 2025-01-05 02:33:48,591] Trial 2 finished with value: 0.833 and parameters: {'C': 0.07171976220946175, 'solver': 'lbfgs', 'class_weight': None}. Best is trial 0 with value: 0.851.
# [I 2025-01-05 02:33:48,886] Trial 3 finished with value: 0.841 and parameters: {'C': 0.4744602919691161, 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.851.
# ...

# %%
configs = [{
    'tokenizer': 'word2vec',
    'model': 'logistic_regression',
    'max_iter': 1000,
    'normalization': False,
    'padding': False,
}]

# %%
pipeline_classification(configs)
# Out:
# [I 2025-01-05 02:34:31,734] A new study created in RDB with name: logistic_regression_word2vec
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 02:34:33,409] Trial 0 finished with value: 0.855 and parameters: {'C': 0.0063739788207322545, 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.855.
# [I 2025-01-05 02:34:38,786] Trial 1 finished with value: 0.862 and parameters: {'C': 2.805836938153945, 'solver': 'liblinear', 'class_weight': None}. Best is trial 1 with value: 0.862.
# [I 2025-01-05 02:34:45,037] Trial 2 finished with value: 0.857 and parameters: {'C': 0.12679627953616535, 'solver': 'lbfgs', 'class_weight': 'balanced'}. Best is trial 1 with value: 0.862.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm',
    'max_iter': 750
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 02:43:28,574] A new study created in RDB with name: svm_count
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2025-01-05 02:43:48,436] Trial 0 finished with value: 0.82 and parameters: {'C': 20.074944457465705, 'kernel': 'rbf', 'gamma': 'scale', 'class_weight': None}. Best is trial 0 with value: 0.82.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ...

# %%
configs = [{
    'tokenizer': 'tfidf',
    'model': 'svm',
    'max_iter': 750,
    'normalization': False
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 02:59:58,066] A new study created in RDB with name: svm_tfidf
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2025-01-05 03:00:27,042] Trial 0 finished with value: 0.753 and parameters: {'C': 2.450007221963536, 'kernel': 'rbf', 'gamma': 'auto', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.753.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ...

# %%
configs = [{
    'tokenizer': 'word2vec',
    'model': 'svm',
    'max_iter': 750,
    'normalization': False,
    'padding': False,
}]

# %%
pipeline_classification(configs)
# Out:
# [I 2025-01-05 03:18:31,961] A new study created in RDB with name: svm_word2vec
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [I 2025-01-05 03:18:34,491] Trial 0 finished with value: 0.679 and parameters: {'C': 3.007559086065899, 'kernel': 'linear', 'gamma': 'scale', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.679.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# ...

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'random_forest'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 03:21:24,503] A new study created in RDB with name: random_forest_count
# [I 2025-01-05 03:21:31,151] Trial 0 finished with value: 0.8 and parameters: {'n_estimators': 156, 'max_depth': None, 'min_samples_split': 10}. Best is trial 0 with value: 0.8.
# [I 2025-01-05 03:21:38,597] Trial 1 finished with value: 0.776 and parameters: {'n_estimators': 358, 'max_depth': 20, 'min_samples_split': 10}. Best is trial 0 with value: 0.8.
# [I 2025-01-05 03:21:45,042] Trial 2 finished with value: 0.78 and parameters: {'n_estimators': 266, 'max_depth': 30, 'min_samples_split': 2}. Best is trial 0 with value: 0.8.
# [I 2025-01-05 03:21:46,256] Trial 3 finished with value: 0.748 and parameters: {'n_estimators': 51, 'max_depth': 20, 'min_samples_split': 3}. Best is trial 0 with value: 0.8.
# ...

# %%
configs = [{
    'tokenizer': 'tfidf',
    'model': 'random_forest',
    'normalization': False
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 03:32:00,814] A new study created in RDB with name: random_forest_tfidf
# [I 2025-01-05 03:32:03,044] Trial 0 finished with value: 0.72 and parameters: {'n_estimators': 187, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 0 with value: 0.72.
# [I 2025-01-05 03:32:06,187] Trial 1 finished with value: 0.713 and parameters: {'n_estimators': 277, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 0 with value: 0.72.
# [I 2025-01-05 03:32:08,031] Trial 2 finished with value: 0.779 and parameters: {'n_estimators': 71, 'max_depth': 30, 'min_samples_split': 6}. Best is trial 2 with value: 0.779.
# [I 2025-01-05 03:32:09,595] Trial 3 finished with value: 0.714 and parameters: {'n_estimators': 125, 'max_depth': 10, 'min_samples_split': 9}. Best is trial 2 with value: 0.779.
# ...

# %%
configs = [{
    'tokenizer': 'word2vec',
    'model': 'random_forest',
    'normalization': False,
    'padding': False,
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# [I 2025-01-05 03:43:17,564] A new study created in RDB with name: random_forest_word2vec
# [I 2025-01-05 03:43:42,993] Trial 0 finished with value: 0.854 and parameters: {'n_estimators': 433, 'max_depth': 10, 'min_samples_split': 8}. Best is trial 0 with value: 0.854.
# [I 2025-01-05 03:44:13,116] Trial 1 finished with value: 0.857 and parameters: {'n_estimators': 416, 'max_depth': 20, 'min_samples_split': 7}. Best is trial 1 with value: 0.857.
# [I 2025-01-05 03:44:23,146] Trial 2 finished with value: 0.848 and parameters: {'n_estimators': 165, 'max_depth': 10, 'min_samples_split': 2}. Best is trial 1 with value: 0.857.
# [I 2025-01-05 03:44:47,617] Trial 3 finished with value: 0.852 and parameters: {'n_estimators': 333, 'max_depth': 30, 'min_samples_split': 7}. Best is trial 1 with value: 0.857.
# ...

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\TextDataset.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...
