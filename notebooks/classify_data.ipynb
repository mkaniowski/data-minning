# %%
from src.classification.pipeline_classification import pipeline_classification

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression'
},{
    'tokenizer': 'word2vec',
    'model': 'logistic_regression'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.65
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.52

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes'
},{
    'tokenizer': 'word2vec',
    'model': 'naive_bayes'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.62
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.50

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm'
},{
    'tokenizer': 'word2vec',
    'model': 'svm'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.61
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'random_forest'
},{
    'tokenizer': 'word2vec',
    'model': 'random_forest'
}]

# %%
pipeline_classification(configs)

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\train_model.py:61: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(model=model, args=training_args, train_dataset=train_dataset, eval_dataset=test_dataset,
#     <div>
#
#       <progress value='19' max='786' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 19/786 00:24 < 18:20, 0.70 it/s, Epoch 0.07/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pipeline_classification(configs)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\pipeline_classification.py:30, in pipeline_classification(configs)
#      27 X_train, X_test, y_train, y_test = make_dataset(df=_df, model_name=model_name)
#      29 # Train the model
# ---> 30 model = train_model(X_train, y_train, X_test, y_test, model_name)
#      32 classify_data(model_name, model, X_test, y_test)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\train_model.py:65, in train_model(X_train, y_train, X_test, y_test, model_name)
#      61 trainer = Trainer(model=model, args=training_args, train_dataset=train_dataset, eval_dataset=test_dataset,
#      62                   tokenizer=tokenizer)
#      64 # Train the model
# ---> 65 trainer.train()
#      67 # Evaluate the model
#      68 trainer.evaluate()
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:2123, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2121         hf_hub_utils.enable_progress_bars()
#    2122 else:
# -> 2123     return inner_training_loop(
#    2124         args=args,
#    2125         resume_from_checkpoint=resume_from_checkpoint,
#    2126         trial=trial,
#    2127         ignore_keys_for_eval=ignore_keys_for_eval,
#    2128     )
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:2486, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2480 with context():
#    2481     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2483 if (
#    2484     args.logging_nan_inf_filter
#    2485     and not is_torch_xla_available()
# -> 2486     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2487 ):
#    2488     # if loss is nan or inf simply add the average of previous logged losses
#    2489     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#    2490 else:
#
# KeyboardInterrupt:
