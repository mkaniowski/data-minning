# %%
from src.classification.pipeline_classification import pipeline_classification
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kanio\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression'
},{
    'tokenizer': 'tfidf',
    'model': 'logistic_regression'
}]

# %%
pipeline_classification(configs)
# Out:
# Accuracy: 0.66
# Accuracy: 0.66

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm'
}, {
    'tokenizer': 'tfidf',
    'model': 'svm'
}]

# %%
pipeline_classification(configs)
# Out:
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy: 0.63
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy: 0.65

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes'
}, {
    'tokenizer': 'tfidf',
    'model': 'naive_bayes'
}]

# %%
pipeline_classification(configs)
# Out:
# Accuracy: 0.61
# Accuracy: 0.61

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\data-minning\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'input_ids'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pipeline_classification(configs)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\pipeline_classification.py:46, in pipeline_classification(configs)
#      43     _df = tokenize_data(df=df, tokenizer=tokenizer)
#      45 # Split the data
# ---> 46 X_train, X_test, y_train, y_test = make_dataset(df=_df, model_name=model_name)
#      48 # Normalize tokens if necessary
#      49 if model_name in ['logistic_regression', 'svm', 'naive_bayes']:
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\data_processing\make_dataset.py:35, in make_dataset(df, test_size, random_state, maxlen, model_name)
#      32 y = label_encoder.fit_transform(y)
#      34 if model_name == "distilbert-base-uncased":
# ---> 35     input_ids = pad_sequences(df['input_ids'].tolist(), maxlen)
#      36     attention_mask = pad_sequences(df['attention_mask'].tolist(), maxlen)
#      38     ids_train, ids_test, mask_train, mask_test, y_train, y_test = train_test_split(
#      39         input_ids, attention_mask, y, test_size=test_size, random_state=random_state
#      40     )
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'input_ids'
