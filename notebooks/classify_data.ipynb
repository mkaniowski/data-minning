# %%
from src.classification.pipeline_classification import pipeline_classification

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression'
},{
    'tokenizer': 'word2vec',
    'model': 'logistic_regression'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.65
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.52

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes'
},{
    'tokenizer': 'word2vec',
    'model': 'naive_bayes'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.62
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.50

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm'
},{
    'tokenizer': 'word2vec',
    'model': 'svm'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.61
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'random_forest'
},{
    'tokenizer': 'word2vec',
    'model': 'random_forest'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.65
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.54

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pipeline_classification(configs)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\pipeline_classification.py:29, in pipeline_classification(configs)
#      26 _df = tokenize_data(df=_df, tokenizer=tokenizer)
#      28 # Split the data
# ---> 29 X_train, X_test, y_train, y_test = make_dataset(df=_df, model_name=model_name)
#      31 # Train the model
#      32 model = train_model(X_train, y_train, X_test, y_test, model_name)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\data_processing\make_dataset.py:53, in make_dataset(df, test_size, random_state, maxlen, model_name)
#      51 # Balance the dataset
#      52 input_ids, y = balance_dataset(input_ids, y)
# ---> 53 attention_mask, _ = balance_dataset(attention_mask, y)
#      55 ids_train, ids_test, mask_train, mask_test, y_train, y_test = train_test_split(input_ids, attention_mask, y,
#      56                                                                                test_size=test_size,
#      57                                                                                random_state=random_state)
#      59 out = (
#      60 {"input_ids": ids_train, "attention_mask": mask_train}, {"input_ids": ids_test, "attention_mask": mask_test},
#      61 y_train, y_test,)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\data_processing\make_dataset.py:29, in balance_dataset(X, y)
#      27 def balance_dataset(X, y):
#      28     smote = SMOTE(random_state=42)
# ---> 29     X_balanced, y_balanced = smote.fit_resample(X, y)
#      30     return X_balanced, y_balanced
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\imblearn\base.py:208, in BaseSampler.fit_resample(self, X, y)
#     187 """Resample the dataset.
#     188
#     189 Parameters
#    (...)
#     205     The corresponding label of `X_resampled`.
#     206 """
#     207 self._validate_params()
# --> 208 return super().fit_resample(X, y)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\imblearn\base.py:106, in SamplerMixin.fit_resample(self, X, y)
#     104 check_classification_targets(y)
#     105 arrays_transformer = ArraysTransformer(X, y)
# --> 106 X, y, binarize_y = self._check_X_y(X, y)
#     108 self.sampling_strategy_ = check_sampling_strategy(
#     109     self.sampling_strategy, y, self._sampling_type
#     110 )
#     112 output = self._fit_resample(X, y)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\imblearn\base.py:161, in BaseSampler._check_X_y(self, X, y, accept_sparse)
#     159     accept_sparse = ["csr", "csc"]
#     160 y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 161 X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     162 return X, y, binarize_y
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\sklearn\utils\validation.py:1320, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    (...)
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
# -> 1320 check_consistent_length(X, y)
#    1322 return X, y
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\sklearn\utils\validation.py:457, in check_consistent_length(*arrays)
#     455 uniques = np.unique(lengths)
#     456 if len(uniques) > 1:
# --> 457     raise ValueError(
#     458         "Found input variables with inconsistent numbers of samples: %r"
#     459         % [int(l) for l in lengths]
#     460     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [7227, 11502]
