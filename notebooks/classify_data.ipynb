# %%
from src.classification.pipeline_classification import pipeline_classification

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# zdrowie -> 5
# Accuracy: 0.38

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# zdrowie -> 5
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Accuracy: 0.50

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# zdrowie -> 5
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=750).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'random_forest'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.65
# Label mapping:
# gospodarka i finanse -> 0
# polityka i prawo -> 1
# relacje miedzynarodowe i bezpieczenstwo -> 2
# Accuracy: 0.54

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# Label mapping:
# militaria -> 0
# sport -> 1
# technologia -> 2
# wiadomosci -> 3
# yapping -> 4
# zdrowie -> 5
# True
# 1
# 0
# NVIDIA GeForce GTX 1060 6GB
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Model is running on: cuda:0
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\TextDataset.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
#     <div>
#
#       <progress value='630' max='630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [630/630 54:01, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.301800</td>
#       <td>2.851966</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.306500</td>
#       <td>0.377232</td>
#     </tr>
#   </tbody>
# </table><p>
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\TextDataset.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\TextDataset.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\TextDataset.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item['labels'] = torch.tensor(self.labels[idx])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pipeline_classification(configs)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\pipeline_classification.py:34, in pipeline_classification(configs)
#      31 # Train the model
#      32 model = train_model(X_train, y_train, X_test, y_test, model_name)
# ---> 34 classify_data(model_name, model, X_test, y_test)
#
# File E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\classify_data.py:29, in classify_data(model_name, model, X_test, y_test)
#      26 test_dataset = TextDataset(X_test_for_prediction, y_test)
#      28 # Predict on the test dataset
# ---> 29 predictions = model.predict(test_dataset)
#      31 # Extract logits and convert to predicted classes
#      32 logits = predictions.predictions
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:4053, in Trainer.predict(self, test_dataset, ignore_keys, metric_key_prefix)
#    4050 start_time = time.time()
#    4052 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 4053 output = eval_loop(
#    4054     test_dataloader, description="Prediction", ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix
#    4055 )
#    4056 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    4057 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:4169, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    4166         batch_size = observed_batch_size
#    4168 # Prediction step
# -> 4169 losses, logits, labels = self.prediction_step(model, inputs, prediction_loss_only, ignore_keys=ignore_keys)
#    4170 main_input_name = getattr(self.model, "main_input_name", "input_ids")
#    4171 inputs_decode = (
#    4172     self._prepare_input(inputs[main_input_name]) if "inputs" in args.include_for_metrics else None
#    4173 )
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:4385, in Trainer.prediction_step(self, model, inputs, prediction_loss_only, ignore_keys)
#    4383 if has_labels or loss_without_labels:
#    4384     with self.compute_loss_context_manager():
# -> 4385         loss, outputs = self.compute_loss(model, inputs, return_outputs=True)
#    4386     loss = loss.mean().detach()
#    4388     if isinstance(outputs, dict):
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\trainer.py:3633, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3631         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3632     inputs = {**inputs, **loss_kwargs}
# -> 3633 outputs = model(**inputs)
#    3634 # Save past state if it exists
#    3635 # TODO: this needs to be fixed and made cleaner later.
#    3636 if self.args.past_index >= 0:
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\accelerate\utils\operations.py:823, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     822 def forward(*args, **kwargs):
# --> 823     return model_forward(*args, **kwargs)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\accelerate\utils\operations.py:811, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     810 def __call__(self, *args, **kwargs):
# --> 811     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\amp\autocast_mode.py:44, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      41 @functools.wraps(func)
#      42 def decorate_autocast(*args, **kwargs):
#      43     with autocast_instance:
# ---> 44         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:1012, in DistilBertForSequenceClassification.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1010 elif self.config.problem_type == "single_label_classification":
#    1011     loss_fct = CrossEntropyLoss()
# -> 1012     loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
#    1013 elif self.config.problem_type == "multi_label_classification":
#    1014     loss_fct = BCEWithLogitsLoss()
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\modules\loss.py:1293, in CrossEntropyLoss.forward(self, input, target)
#    1292 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# -> 1293     return F.cross_entropy(
#    1294         input,
#    1295         target,
#    1296         weight=self.weight,
#    1297         ignore_index=self.ignore_index,
#    1298         reduction=self.reduction,
#    1299         label_smoothing=self.label_smoothing,
#    1300     )
#
# File ~\anaconda3\envs\data-minning\Lib\site-packages\torch\nn\functional.py:3479, in cross_entropy(input, target, weight, size_average, ignore_index, reduce, reduction, label_smoothing)
#    3477 if size_average is not None or reduce is not None:
#    3478     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3479 return torch._C._nn.cross_entropy_loss(
#    3480     input,
#    3481     target,
#    3482     weight,
#    3483     _Reduction.get_enum(reduction),
#    3484     ignore_index,
#    3485     label_smoothing,
#    3486 )
#
# RuntimeError: "nll_loss_forward_reduce_cuda_kernel_2d_index" not implemented for 'Int'
