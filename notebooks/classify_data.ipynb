# %%
from src.classification.pipeline_classification import pipeline_classification
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kanio\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'logistic_regression'
},{
    'tokenizer': 'tfidf',
    'model': 'logistic_regression'
}]

# %%
pipeline_classification(configs)
# Out:
# Accuracy: 0.66
# Accuracy: 0.52

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'svm'
}, {
    'tokenizer': 'tfidf',
    'model': 'svm'
}]

# %%
pipeline_classification(configs)
# Out:
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=1000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy: 0.63
# Accuracy: 0.52

# %%
configs = [{
    'tokenizer': 'count',
    'model': 'naive_bayes'
}, {
    'tokenizer': 'tfidf',
    'model': 'naive_bayes'
}]

# %%
pipeline_classification(configs)
# Out:
# Accuracy: 0.61
# Accuracy: 0.52

# %%
configs = [{
    'tokenizer': 'distilbert-base-uncased',
    'model': 'distilbert-base-uncased'
}]

# %%
pipeline_classification(configs)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# E:\Michal\Dokumenty\Studia\DM\data-minning\src\classification\pipeline_classification.py:87: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='456' max='456' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [456/456 10:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.497700</td>
#       <td>1.338868</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.112100</td>
#       <td>1.023503</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.995200</td>
#       <td>0.849276</td>
#     </tr>
#   </tbody>
# </table><p>
# Confusion Matrix:
# [[  0   0  44  19   0   0]
#  [  0   0  13  15   0   0]
#  [  0   0 295  20   0   1]
#  [  0   0  60  57   7   6]
#  [  0   0   2   1  15   0]
#  [  0   0   2   3   0  48]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        63
#            1       0.00      0.00      0.00        28
#            2       0.71      0.93      0.81       316
#            3       0.50      0.44      0.47       130
#            4       0.68      0.83      0.75        18
#            5       0.87      0.91      0.89        53
#
#     accuracy                           0.68       608
#    macro avg       0.46      0.52      0.49       608
# weighted avg       0.57      0.68      0.62       608
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\kanio\anaconda3\envs\data-minning\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
